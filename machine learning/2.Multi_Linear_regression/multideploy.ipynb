# %%
import pickle

# %%
loaded_model=pickle.load(open(r"D:\python\machine learning\2.Multi_Linear_regression\finalized_model_Mul_linear.sav",'rb'))
result=loaded_model.predict([[1234,345,4565,1,0]])
# Out:
# C:\python\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[43994.79745873]])
