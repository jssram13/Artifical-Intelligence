# %%
import pickle

# %%
loaded_model=pickle.load(open(r"D:\python\machine learning\finalized_model_linear.sav",'rb'))
result=loaded_model.predict([[10]])
# Out:
# C:\python\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[120380.00420313]])
